# %% [markdown]
# # 5 | Factoring

# %% [markdown]
# ><b>Dr J H Klopper</b></p>
# >Department of Biostatistics and Bioinformatics</br>
# >Milken Institute School of Public Health</br>
# >George Washington University

# %% [markdown]
# <p xmlns:cc="http://creativecommons.org/ns#" xmlns:dct="http://purl.org/dc/terms/"><span property="dct:title">This chapter of Algebra for Health Data Science</span> by <span property="cc:attributionName">Dr JH Klopper</span> is licensed under <a href="http://creativecommons.org/licenses/by-nc-nd/4.0/?ref=chooser-v1" target="_blank" rel="license noopener noreferrer" style="display:inline-block;">Attribution-NonCommercial-NoDerivatives 4.0 International<img style="height:22px!important;margin-left:3px;vertical-align:text-bottom;" src="https://mirrors.creativecommons.org/presskit/icons/cc.svg?ref=chooser-v1"><img style="height:22px!important;margin-left:3px;vertical-align:text-bottom;" src="https://mirrors.creativecommons.org/presskit/icons/by.svg?ref=chooser-v1"><img style="height:22px!important;margin-left:3px;vertical-align:text-bottom;" src="https://mirrors.creativecommons.org/presskit/icons/nc.svg?ref=chooser-v1"><img style="height:22px!important;margin-left:3px;vertical-align:text-bottom;" src="https://mirrors.creativecommons.org/presskit/icons/nd.svg?ref=chooser-v1"></a></p>

# %% [markdown]
# - Watch the pencil and paper video lecture [HERE](https://youtu.be/0bgGgAgfKYo)
#
# - Watch the Python video lecture [HERE](https://youtu.be/WWQB73waZAk)

# %% [markdown]
# ## 5.1 Packages used in this chapter

# %% [markdown]
# Below, we import only the functions that are used in this chapter instead of importing the entire package. To do this we use the `from` and `import` keywords.

# %%
from sympy import init_printing, symbols, Rational, gcd

# %% [markdown]
# The `init_printing` function is used to display the output of `sympy` code in mathematical notation.

# %%
init_printing()

# %% [markdown]
# ## 5.2 Introduction

# %% [markdown]
# In the previous chapter, we considered the expansion of expressions through the use of the distribution. In this chapter, we will consider the reverse process, that of factoring. Factoring is the process of breaking down an expression into its constituent parts. This is a very important process in algebra, as it allows us to simplify expressions and solve equations.

# %% [markdown]
# ## 5.3 Polynomials

# %% [markdown]
# Until now we have explored many expressions. Many of them have been polyomials. In this section, we formely define polynomials.

# %% [markdown]
# __Definition 5.3.1__ A <span style="color:green">__polynomial__</span> is a mathematical expression of constants and variables combined using addition, subtraction, multiplication, and non-negative integer exponents, defined in __Equation 5.3.1__, where $a_{i}$ are constants and $x$ is a variable.

# %% [markdown]
# $$
# \begin{equation}
# a_{n}x^{n} + a_{n-1}x^{n-1} + \cdots + a_{2}x^{2} + a_{1}x + a_{0}
# \end{equation}
# \tag{Equation 5.3.1}
# $$

# %% [markdown]
# __Definition 5.3.2__ The constants $a_{i}$ in __Equation 5.3.1__ are called the <span style="color:green">__coefficients__</span> of the polynomial.

# %% [markdown]
# __Definition 5.3.3__ The <span style="color:green">__degree__</span> of the polynomial is the highest exponent of the variable $x$.

# %% [markdown]
# In the case that $a_{n} \neq 0$ in __Equation 5.3.1__, the polynomial is said to be of degree $n$.

# %% [markdown]
# __Problem 5.3.1__ Determine of the expression in __Equation 5.3.2__ is a polynomial. If so, determine the degree of the polynomial.

# %% [markdown]
# $$
# \begin{equation}
# 3x^{4} + 2x^{3} + 5x^{2} + 7x + 1
# \end{equation}
# \tag{Equation 5.3.2}
# $$

# %% [markdown]
# The expression in __Equation 5.3.2__ is indeed a polynomial as follows the definition in __Equation 5.3.1__. The highest power of the variable $x$ is $4$ and hence the polynomial is of degree 4 or a $4^{\text{th}}$-degree polynomial.

# %% [markdown]
# __Definition  5.3.4__ A <span style="color:green">__quadratic polynomial__</span> is a polynomial of degree $2$.

# %% [markdown]
# __Definition 5.3.5__ A <span style="color:green">__cubic polynomial__</span> is a polynomial of degree $3$.

# %% [markdown]
# __Definition 5.3.6__ A <span style="color:green">__quartic polynomial__</span> is a polynomial of degree $4$.

# %% [markdown]
# __Definition 5.3.7__ A <span style="color:green">__quintic polynomial__</span> is a polynomial of degree $5$.

# %% [markdown]
# Note that polynomials as defined in __Equation 5.3.1__ only contain a single variable.

# %% [markdown]
# ## 5.4 Factoring common elements

# %% [markdown]
# In the simplest cases of an expression, we can factor out a common element, whether they are constants or variable. We start by a common variable among the terms of an expression.

# %% [markdown]
# __Problem 5.4.1__ Factor out the common variable $x$ from the expression in __Equation 5.4.1__.

# %% [markdown]
# $$
# \begin{equation}
# x^{2} + 3x
# \end{equation}
# \tag{Equation 5.4.1}
# $$

# %% [markdown]
# We note that the variable $x$ is in both terms of the exprerssion and can be factorized as shown in __Equation 5.4.2__.

# %% [markdown]
# $$
# \begin{equation}
# x^{2} + 3x = x(x + 3)
# \end{equation}
# \tag{Equation 5.4.2}
# $$

# %% [markdown]
# Distribution of the solution can be used to confirm the result as $x(x+3) = x^{2}+3x$. We can also use the `factor` method in `sympy` to confirm the result. We start by defining the mathematical symbol $x$ and assign ot to the variable `x`.

# %%
# Define the symbol x
x = symbols('x')

# %%
# Factor the polynomial x^2 + 3x
(x**2 + 3*x).factor()
# Out:
# x⋅(x + 3)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.4.1</b></span> Factor out the common variable $x$ from the expression $x^{3}-2x^{2}+x$.

# %% [markdown]
# Some examples of factoring involves the constants. In this case, it is best to look for the greatest common divisor.

# %% [markdown]
# __Definition 5.4.1__ The <span style="color:green">__greatest common divisor__</span> (GCD) of two or more integers is the largest positive integer that divides each of the integers.

# %% [markdown]
# __Problem 5.4.2__ Factor out the common constants or variables from the expression in __Equation 5.4.3__.

# %% [markdown]
# $$
# \begin{equation}
# 6x^{2} + 9y
# \end{equation}
# \tag{Equation 5.4.3}
# $$

# %% [markdown]
# There are no common variables. We note that $3$ divides both $6$ and $9$ and is factored out as shown in __Equation 5.4.4__.

# %% [markdown]
# $$
# \begin{equation}
# 6x^{2} + 9y = 3(2x^{2} + 3y)
# \end{equation}
# \tag{Equation 5.4.4}
# $$

# %% [markdown]
# We verify the result using the `factor` method in `sympy` after defining the mathematical symbol $y$ and assigning them to the variables `y`.

# %%
# Define the symbol y
y = symbols('y')

# %%
# Verify the result
(6 * x**2 + 9 * y).factor()
# Out:
#   ⎛   2      ⎞
# 3⋅⎝2⋅x  + 3⋅y⎠

# %% [markdown]
# __Problem 5.4.3__ Factor out the common term (with constants and or variables) from the expression in __Equation 5.4.5__.

# %% [markdown]
# $$
# \begin{equation}
# 216x+450y
# \end{equation}
# \tag{Equation 5.4.5}
# $$

# %% [markdown]
# It can be difficult to calculate a GCD. We note the following observations.

# %% [markdown]
# - Any integer, is the product of two integers
# - None of the two integers used in the product can be more than half the original integer
# - We only need to consider integers up to the square root of the original integer
# - Any integer is the product of prime numbers
# - The GCD of two numbers is the same as the GCD of the remainder of the division of the larger number by the smaller number and the smaller number.

# %% [markdown]
# Instead of considering these arithmetical properties, we calculate the greatest common divisor using the `gcd` function in `sympy`.

# %%
# Return the greatest common divisor of 216 and 450
gcd(216, 450)
# Out:
# 18

# %% [markdown]
# We note that $18$ is the GCD of $216$ and $450$. This means that both these values can be divided by $18$ without a remainder. Below, we calculate the divisions.

# %%
216 / 18
# Out:
# 12.0

# %%
450 / 18
# Out:
# 25.0

# %% [markdown]
# The solution is therefor as shown in __Equation 5.4.6__.

# %% [markdown]
# $$
# \begin{equation}
# 216x+450y = 18(12x+25y)
# \end{equation}
# \tag{Equation 5.4.6}
# $$

# %% [markdown]
# We verify these results using the `factor` method in `sympy`.

# %%
# Verify the result
(216 * x + 450 * y).factor()
# Out:
# 18⋅(12⋅x + 25⋅y)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.4.2</b></span> Calculate the GCD of $2345$ and $25$. Hint: Make use of the fact that the GCD of the two numbers will also be the GCD of the smallest number, which is $25$, and the remainder of $2345 \div 25$, which is $20$.

# %% [markdown]
# The common elements across terms may include constants and variable.

# %% [markdown]
# __Problem 5.4.4__ Factor out the common constants and variables from the expression in __Equation 5.4.7__.

# %% [markdown]
# $$
# \begin{equation}
# 6x^{2} + 9xy
# \end{equation}
# \tag{Equation 5.4.7}
# $$

# %% [markdown]
# The solution is as shown in __Equation 5.4.8__.

# %% [markdown]
# $$
# \begin{equation}
# 6x^{2} + 9xy = 3x(2x + 3y)
# \end{equation}
# \tag{Equation 5.4.8}
# $$

# %% [markdown]
# We confirm the result in `sympy`.

# %%
# Verify the result
(6 * x**2 + 9 * x * y).factor()
# Out:
# 3⋅x⋅(2⋅x + 3⋅y)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.4.3</b></span> Factor out the common constants and variables from the expression $12x^{3}y+36x^{2}y$.

# %% [markdown]
# ## 5.5 Factoring quadratic polynomials

# %% [markdown]
# In this section we explore the factoring of quadratic ($2^{\text{nd}}$-degree) polynomials $a_{2}x^{2} + a_{1} x + a_{0}$, where $a_{2} \ne 0$.

# %% [markdown]
# To factor quadratic expression, we follow a few steps. First, we write the expression in decreasing order of the exponents. As an exmple, we will use the quadratic expression $x^{2}+5x+6$, which is in decreasing order of the powers of the variable $x$.

# %% [markdown]
# Next, we write two sets of parentheses as shown in __Equation 5.5.1__.

# %% [markdown]
# $$
# \begin{equation}
# (x \ \ \ )(x \ \ \ )
# \end{equation}
# \tag{Equation 5.5.1}
# $$

# %% [markdown]
# Next, we have to consider all the pairs of number that multiply to get $a_{0}=6$. We might try $+3$ and $+2$. These are added to the parentheses as shown in __Equation 5.5.2__.

# %% [markdown]
# $$
# \begin{equation}
# (x + 3)(x + 2)
# \end{equation}
# \tag{Equation 5.5.2}
# $$

# %% [markdown]
# Distribution confirms that we have the correct solution as shown in __Equation 5.5.3__.

# %% [markdown]
# $$
# \begin{equation}
# (x + 3)(x + 2) = x^{2} + 2x + 3 x + 6 = x^{2} + 5x + 6
# \end{equation}
# \tag{Equation 5.5.3}
# $$

# %% [markdown]
# In this example we had that $a_{2}=1$. This is not always the case.

# %% [markdown]
# __Problem 5.5.1__ Factor the quadratic expression in __Equation 5.5.4__.

# %% [markdown]
# $$
# \begin{equation}
# 2x^{2} + 7x + 3
# \end{equation}
# \tag{Equation 5.5.4}
# $$

# %% [markdown]
# Noe $a_{2}=2$. One pair of numbers that multiply to $2$ is $+2$ and $+1$. We use two pairs of parentheses are before as shown in __Equation 5.5.5__.

# %% [markdown]
# $$
# \begin{equation}
# (2x \ \ \ )(x \ \ \ )
# \end{equation}
# \tag{Equation 5.5.5}
# $$

# %% [markdown]
# Now we have to think of pairs of numbers that multiply to $3$, but such that the two terms that will contain $x$ will add to $7$. The only pair of numbers that satisfy this condition is $+1$ and $+3$. We add these to the parentheses as shown in __Equation 5.5.6__, where we also use distribution to confirm our factorization.

# %% [markdown]
# $$
# \begin{equation}
# (2x + 1)(x + 3) = 2x^{2} +6x + 1x +3 = 2x^{2} + 7x + 3
# \end{equation}
# \tag{Equation 5.5.6}
# $$

# %% [markdown]
# We use `sympy` to confirm the result.

# %%
# Verify the result
(2 * x**2 + 7 * x + 3).factor()
# Out:
# (x + 3)⋅(2⋅x + 1)

# %% [markdown]
# __Problem 5.5.2__ Factor the quadratic expression in __Equation 5.5.7__.

# %% [markdown]
# $$
# \begin{equation}
# 2x^{2} - 5x - 12
# \end{equation}
# \tag{Equation 5.5.7}
# $$

# %% [markdown]
# The results are shown in __Equation 5.5.8__, where we also use distribution to confirm the result.

# %% [markdown]
# $$
# \begin{equation}
# (2x + 3)(x - 4) = 2x^{2} - 8x + 3x - 12 = 2x^{2} - 5x - 12
# \end{equation}
# \tag{Equation 5.5.8}
# $$

# %% [markdown]
# We also use `sympy` to verify the result.

# %%
# Verify the result
(2 * x**2 - 5 * x - 12).factor()
# Out:
# (x - 4)⋅(2⋅x + 3)

# %% [markdown]
# __Problem 5.5.3__ Factor the quadratic expression in __Equation 5.5.9__.

# %% [markdown]
# $$
# \begin{equation}
# 40 x^{2} - 40 x -240
# \end{equation}
# \tag{Equation 5.5.9}
# $$

# %% [markdown]
# We note that we can also factor the GCD before factoring. The result is shown in __Equation 5.5.10__, and verified using `sympy`.

# %% [markdown]
# $$
# \begin{equation}
# 40 x^{2} - 40 x -240 = 40(x^{2} - x - 6) = 40(x + 2)(x - 3)
# \end{equation}
# \tag{Equation 5.5.10}
# $$

# %%
# Verify the result
(40 * x**2 - 40 * x - 240).factor()
# Out:
# 40⋅(x - 3)⋅(x + 2)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.5.1</b></span> Factor the quadratic expression $2 x^{2} + 6 x - 20$.

# %% [markdown]
# Some of the simplest polynomials to factor are those that can be written as $x^{2} - a^{2}$. These are called __difference of squares__. The results is simply $(x-a)(x+a)$. Note that distribution shows that the terms containing $x$ cancel out.

# %% [markdown]
# __Problem 5.5.4__ Factor the difference of squares in __Equation 5.5.11__.

# %% [markdown]
# $$
# \begin{equation}
# x^{2} - 9
# \end{equation}
# \tag{Equation 5.5.11}
# $$

# %% [markdown]
# The result is shown in __Equation 5.5.12__, and confirmed using `sympy`.

# %% [markdown]
# $$
# \begin{equation}
# x^{2} - 9 = (x^{2} - 3^{2}) = (x - 3)(x + 3)
# \end{equation}
# \tag{Equation 5.5.12}
# $$

# %%
# Verify the result
(x**2 - 9).factor()
# Out:
# (x - 3)⋅(x + 3)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.5.2</b></span> Factor the difference of squares $x^{2} - 400$.

# %% [markdown]
# __Problem 5.5.5__ Factor the difference of squares in __Equation 5.5.13__.

# %% [markdown]
# $$
# \begin{equation}
# 25x^{2} - 81y^{2}
# \end{equation}
# \tag{Equation 5.5.13}
# $$

# %% [markdown]
# The result is shown in __Equation 5.5.14__, and confirmed using `sympy`.

# %% [markdown]
# $$
# \begin{equation}
# 25x^{2} - 81y^{2} = (5x)^{2} - (9y)^{2} = (5x - 9y)(5x + 9y)
# \end{equation}
# \tag{Equation 5.5.14}
# $$

# %%
# Verify the result
(25 * x**2 - 81 * y**2).factor()
# Out:
# (5⋅x - 9⋅y)⋅(5⋅x + 9⋅y)

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.5.3</b></span> Factor the difference of squares $4x^{2} - 9y^{2}$.

# %% [markdown]
# We can also factor perfect cubes, $a^{3} - b^{3}$. The general form for factoring perfect cubes is shown in __Equation 5.5.15__.

# %% [markdown]
# $$
# \begin{equation}
# a^{3} - b^{3} = (a - b)(a^{2} + ab + b^{2})
# \end{equation}
# \tag{Equation 5.5.15}
# $$

# %% [markdown]
# Note that $a^{2} + ab + b^{2}$ cannot be factored.

# %% [markdown]
# __Problem 5.5.6__ Factor the perfect cubes in __Equation 5.5.16__.

# %% [markdown]
# $$
# \begin{equation}
# 8x^{3} - 27
# \end{equation}
# \tag{Equation 5.5.16}
# $$

# %% [markdown]
# The result follows __Equation 5.5.15__ and is shown in __Equation 5.5.17__, where $a=2x$ and $b=3$.

# %% [markdown]
# $$
# \begin{equation}
# 8x^{3} - 27 = (2x)^{3} - 3^{3} = (2x - 3)(4x^{2} + 6x + 9)
# \end{equation}
# \tag{Equation 5.5.17}
# $$

# %% [markdown]
# We verify the result using `sympy`.

# %%
# Verify the result
(8 * x**3 - 27).factor()
# Out:
#           ⎛   2          ⎞
# (2⋅x - 3)⋅⎝4⋅x  + 6⋅x + 9⎠

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.5.4</b></span> Factor the perfect cubes $27x^{3} - 64$.

# %% [markdown]
# We also have the sum of perfect cubes shown in __Equation 5.5.18__.

# %% [markdown]
# $$
# \begin{equation}
# a^{3} + b^{3} = (a + b)(a^{2} - ab + b^{2})
# \end{equation}
# \tag{Equation 5.5.18}
# $$

# %% [markdown]
# __Problem 5.5.7__ Factor the sum of perfect cubes in __Equation 5.5.19__.

# %% [markdown]
# $$
# \begin{equation}
# 27x^{3} + 8
# \end{equation}
# \tag{Equation 5.5.19}
# $$

# %% [markdown]
# We see the result in __Equation 5.5.20__, where $a=3x$ and $b=2$.

# %% [markdown]
# $$
# \begin{equation}
# 27x^{3} + 8 = (3x)^{3} + 2^{3} = (3x + 2)(9x^{2} - 6x + 4)
# \end{equation}
# \tag{Equation 5.5.20}
# $$

# %% [markdown]
# We verify the result using `sympy`.

# %%
# Verify the result
(27 * x**3 + 8).factor()
# Out:
#           ⎛   2          ⎞
# (3⋅x + 2)⋅⎝9⋅x  - 6⋅x + 4⎠

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.5.5</b></span> Factor the sum of perfect cubes $64x^{3} + 125$.

# %% [markdown]
# ## 5.6 Factoring rational expressions

# %% [markdown]
# Polynomials can appear in the numerrator and denominator of a rational expression. In this case, we can factor the numerator and denominator separately. Once this is done, we can cancel out common factors.

# %% [markdown]
# __Problem 5.6.1__ Factor the rational expression in __Equation 5.6.1__.

# %% [markdown]
# $$
# \begin{equation}
# \frac{2x^{2} + 7x + 6}{x^{2} - 4}
# \end{equation}
# \tag{Equation 5.6.1}
# $$

# %% [markdown]
# We see the solution in __Equation 5.6.2__.

# %% [markdown]
# $$
# \begin{equation}
# \frac{2x^{2} + 7x + 6}{x^{2} - 4} = \frac{(2x + 3)(x + 2)}{(x + 2)(x - 2)} = \frac{2x + 3}{x - 2}
# \end{equation}
# \tag{Equation 5.6.2}
# $$

# %% [markdown]
# In __Equation 5.6.2__, we see that the factor $(x+2)$ is common in the numerator and in the denominator and cancels out. We verify the result using `sympy`.

# %%
# Print the problem using sympy
(2 * x**2 + 7 * x + 6) / (x**2 - 4)
# Out:
#    2
# 2⋅x  + 7⋅x + 6
# ──────────────
#      2
#     x  - 4

# %%
# Verify the result
((2 * x**2 + 7 * x + 6) / (x**2 - 4)).factor()
# Out:
# 2⋅x + 3
# ───────
#  x - 2

# %% [markdown]
# <span style="color:royalblue"><b>Homework 5.6.1</b></span> Factor the rational expression in __Equation 5.6.3__.

# %% [markdown]
# $$
# \frac{2x^{2} + 5x + 3}{x^{2} - 1}
# \tag{Equation 5.6.3}
# $$

# %% [markdown]
# In chapters 7 and 8 we will learn more about factoring.
